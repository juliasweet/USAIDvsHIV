# %%
import pandas as pd

# %%
import os

# %%
usaid = pd.read_csv("USAID.csv")
# Out:
# C:\Users\julia\anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
usaid.head()
# Out:
#    country_id country_code country_name  region_id             region_name  \
# 0           4          AFG  Afghanistan          4  South and Central Asia
# 1           4          AFG  Afghanistan          4  South and Central Asia
# 2           4          AFG  Afghanistan          4  South and Central Asia
# 3           4          AFG  Afghanistan          4  South and Central Asia
# 4           4          AFG  Afghanistan          4  South and Central Asia
#
#    income_group_id   income_group_name income_group_acronym  \
# 0              1.0  Low Income Country                  LIC
# 1              1.0  Low Income Country                  LIC
# 2              1.0  Low Income Country                  LIC
# 3              1.0  Low Income Country                  LIC
# 4              1.0  Low Income Country                  LIC
#
#    implementing_agency_id implementing_agency_acronym  ...  \
# 0                       7                         DOD  ...
# ...

# %%
usaid.columns
# Out:
# Index(['country_id', 'country_code', 'country_name', 'region_id',
#        'region_name', 'income_group_id', 'income_group_name',
#        'income_group_acronym', 'implementing_agency_id',
#        'implementing_agency_acronym', 'implementing_agency_name',
#        'implementing_subagency_id', 'subagency_acronym', 'subagency_name',
#        'channel_category_id', 'channel_category_name',
#        'channel_subcategory_id', 'channel_subcategory_name', 'channel_id',
#        'channel_name', 'dac_category_id', 'dac_category_name',
#        'dac_sector_code', 'dac_sector_name', 'dac_purpose_code',
#        'dac_purpose_name', 'funding_account_id', 'funding_account_name',
#        'funding_agency_id', 'funding_agency_name', 'funding_agency_acronym',
#        'assistance_category_id', 'assistance_category_name',
#        'aid_type_group_id', 'aid_type_group_name', 'activity_id',
#        'activity_name', 'activity_project_number', 'activity_start_date',
# ...

# %%
clean1 = usaid.drop(columns= ['country_id', 'country_code', 'region_id',
    'income_group_id', 
       'income_group_acronym', 'implementing_agency_id',
       'implementing_subagency_id', 'subagency_acronym', 
       'channel_category_id', 
       'channel_subcategory_id',  'channel_id',
       'channel_name', 'dac_category_id', 
       'dac_sector_code', 'dac_purpose_code',
      'funding_account_id', 
       'funding_agency_id',  
 'activity_id',
      'activity_project_number', 'activity_start_date',
       'activity_end_date', 'transaction_type_id', 
        'USG_sector_id',
       'submission_id'])

# %%
clean1.head()
# Out:
#   country_name             region_name   income_group_name  \
# 0  Afghanistan  South and Central Asia  Low Income Country
# 1  Afghanistan  South and Central Asia  Low Income Country
# 2  Afghanistan  South and Central Asia  Low Income Country
# 3  Afghanistan  South and Central Asia  Low Income Country
# 4  Afghanistan  South and Central Asia  Low Income Country
#
#   implementing_agency_acronym implementing_agency_name  subagency_name  \
# 0                         DOD    Department of Defense  not applicable
# 1                         DOD    Department of Defense  not applicable
# 2                         DOD    Department of Defense  not applicable
# 3                         DOD    Department of Defense  not applicable
# 4                         DOD    Department of Defense  not applicable
#
#   channel_category_name    channel_subcategory_name dac_category_name  \
# 0            Government  Government - United States        Governance
# ...

# %%
clean1.columns
# Out:
# Index(['country_name', 'region_name', 'income_group_name',
#        'implementing_agency_acronym', 'implementing_agency_name',
#        'subagency_name', 'channel_category_name', 'channel_subcategory_name',
#        'dac_category_name', 'dac_sector_name', 'dac_purpose_name',
#        'funding_account_name', 'funding_agency_name', 'funding_agency_acronym',
#        'assistance_category_id', 'assistance_category_name',
#        'aid_type_group_id', 'aid_type_group_name', 'activity_name',
#        'transaction_type_name', 'fiscal_year', 'current_amount',
#        'constant_amount', 'USG_sector_name'],
#       dtype='object')

# %%
clean1 = clean1.drop(columns = ['assistance_category_id','aid_type_group_id'])

# %%
clean1.columns
# Out:
# Index(['country_name', 'region_name', 'income_group_name',
#        'implementing_agency_acronym', 'implementing_agency_name',
#        'subagency_name', 'channel_category_name', 'channel_subcategory_name',
#        'dac_category_name', 'dac_sector_name', 'dac_purpose_name',
#        'funding_account_name', 'funding_agency_name', 'funding_agency_acronym',
#        'assistance_category_name', 'aid_type_group_name', 'activity_name',
#        'transaction_type_name', 'fiscal_year', 'current_amount',
#        'constant_amount', 'USG_sector_name'],
#       dtype='object')

# %%
clean1["region_name"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                South and Central Asia
# 1                South and Central Asia
# 2                South and Central Asia
# 3                South and Central Asia
# 4                South and Central Asia
# 5                South and Central Asia
# 6                South and Central Asia
# 7                South and Central Asia
# 8                South and Central Asia
# 9                South and Central Asia
# 10               South and Central Asia
# 11               South and Central Asia
# 12               South and Central Asia
# 13         Middle East and North Africa
# 14               South and Central Asia
# 15               South and Central Asia
# 16               South and Central Asia
# 17               South and Central Asia
# 18         Middle East and North Africa
# 19         Middle East and North Africa
# 20         Middle East and North Africa
# 21                   Europe and Eurasia
# ...

# %%
ssa = clean1.loc[clean1["region_name"]=="Sub-Saharan Africa", :]

# %%
ssa.head()
# Out:
#                   country_name         region_name   income_group_name  \
# 437           Congo (Kinshasa)  Sub-Saharan Africa  Low Income Country
# 513         West Africa Region  Sub-Saharan Africa                 NaN
# 517  Sub-Saharan Africa Region  Sub-Saharan Africa                 NaN
# 633                   Tanzania  Sub-Saharan Africa  Low Income Country
# 637  Sub-Saharan Africa Region  Sub-Saharan Africa                 NaN
#
#     implementing_agency_acronym          implementing_agency_name  \
# 437                       STATE               Department of State
# 513                         DOD             Department of Defense
# 517                       STATE               Department of State
# 633                         MCC  Millennium Challenge Corporation
# 637                       STATE               Department of State
#
#                           subagency_name channel_category_name  \
# 437  Population, Refugees, and Migration          Multilateral
# ...

# %%
ssa2 = ssa.loc[(ssa["fiscal_year"]== 2000)|(ssa["fiscal_year"]== 2001)|(ssa["fiscal_year"]== 2002)|
              (ssa["fiscal_year"]== 2003)|(ssa["fiscal_year"]== 2004)|(ssa["fiscal_year"]== 2005)|
              (ssa["fiscal_year"]== 2006)|(ssa["fiscal_year"]== 2007)|(ssa["fiscal_year"]== 2008)|
              (ssa["fiscal_year"]== 2009)|(ssa["fiscal_year"]== 2010)|(ssa["fiscal_year"]== 2011)|
              (ssa["fiscal_year"]== 2012)|(ssa["fiscal_year"]== 2013)|(ssa["fiscal_year"]== 2014)|
              (ssa["fiscal_year"]== 2015)|(ssa["fiscal_year"]== 2016)|(ssa["fiscal_year"]== 2017)]

# %%
ssa2.head()
# Out:
#          country_name         region_name            income_group_name  \
# 278601  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278602  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278603  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278604  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278605  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
#
#        implementing_agency_acronym                   implementing_agency_name  \
# 278601                       USAID  U.S. Agency for International Development
# 278602                       USAID  U.S. Agency for International Development
# 278603                       USAID  U.S. Agency for International Development
# 278604                       USAID  U.S. Agency for International Development
# 278605                       USAID  U.S. Agency for International Development
#
#                                            subagency_name  \
# ...

# %%
HIV = ssa2.loc[ssa2["USG_sector_name"]=="HIV/AIDS"]

# %%
HIV.head()
# Out:
#          country_name         region_name            income_group_name  \
# 278601  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278602  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278604  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278605  Cote d'Ivoire  Sub-Saharan Africa  Lower Middle Income Country
# 278626          Kenya  Sub-Saharan Africa  Lower Middle Income Country
#
#        implementing_agency_acronym                   implementing_agency_name  \
# 278601                       USAID  U.S. Agency for International Development
# 278602                       USAID  U.S. Agency for International Development
# 278604                       USAID  U.S. Agency for International Development
# 278605                       USAID  U.S. Agency for International Development
# 278626                       USAID  U.S. Agency for International Development
#
# ...

# %%
HIV.shape
# Out:
# (19306, 22)

# %%
HIV.to_csv("ssa_HIV.csv")

# %%
# Delete original file; it's way too big for your repo
